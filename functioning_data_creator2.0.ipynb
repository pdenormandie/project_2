# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# !pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (0.1.72)
# Requirement already satisfied: requests>=2.26 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: lxml>=4.5.1 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2.0.4)

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
adbe = 'ADBE'

# %%
adbe_df = yf.download(adbe)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
adbe_df['Returns'] = adbe_df["Adj Close"].pct_change()

# %%
adbe_df.drop(["Open","High", "Low", "Close", "Adj Close", "Volume"], axis=1, inplace=True)

# %%
adbe_df
# Out:
#              Returns
# Date
# 1986-08-13       NaN
# 1986-08-14  0.055552
# 1986-08-15 -0.017543
# 1986-08-18 -0.035712
# 1986-08-19  0.018517
# ...              ...
# 2022-06-27 -0.017152
# 2022-06-28 -0.040517
# 2022-06-29  0.007849
# 2022-06-30 -0.006621
# 2022-07-01 -0.007505
#
# [9045 rows x 1 columns]

# %%
adbe_df = adbe_df.reset_index(drop=True).dropna()

# %%
adbe_df2 = adbe_df * adbe_df

result = pd.concat([adbe_df, adbe_df, adbe_df], axis=1)

# %%
result
# Out:
#        Returns   Returns   Returns
# 1     0.055552  0.055552  0.055552
# 2    -0.017543 -0.017543 -0.017543
# 3    -0.035712 -0.035712 -0.035712
# 4     0.018517  0.018517  0.018517
# 5     0.000000  0.000000  0.000000
# ...        ...       ...       ...
# 9040 -0.017152 -0.017152 -0.017152
# 9041 -0.040517 -0.040517 -0.040517
# 9042  0.007849  0.007849  0.007849
# 9043 -0.006621 -0.006621 -0.006621
# 9044 -0.007505 -0.007505 -0.007505
#
# [9044 rows x 3 columns]

# %%
iris = result

# %%
x_reduced = PCA(n_components=3).fit_transform(iris)

# %%
fig = plt.figure()
axes = Axes3D(fig)
axes.set_title("Iris Dataset by PCA", size=14)
axes.set_xlabel("First eigenvector")
axes.set_ylabel("Second eigenvector")
axes.set_zlabel("Third eigenvector")
axes.w_xaxis.set_ticklabels(())
axes.w_yaxis.set_ticklabels(())
axes.w_zaxis.set_ticklabels(())
axes.scatter(x_reduced[:,0],x_reduced[:,1],x_reduced[:,2])
# Out:
# /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.

# %%
# imports from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
import pylab
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
# %matplotlib inline
# %pylab inline
import matplotlib
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
matplotlib.style.use("seaborn")




#TSNE(3)
data = TSNE(n_components=3, random_state=0).fit_transform(x_reduced)
x, y, z = list(zip(*data))

fig = pylab.figure(dpi=256)
somefunc=fig.get_size_inches()
fig.set_figheight(somefunc[0])
fig.set_figwidth(somefunc[1])
ax = fig.add_subplot(111, projection = '3d')
sc = ax.scatter(x, y, z)
fig.set_color(color= ['black', 'blue', 'green'])
fig.savefig("adbe.png")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /Users/pdenormandie/opt/anaconda3/envs/dev/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ml/gd9n1t7n4tqftj4c2btcrqrw0000gn/T/ipykernel_20464/4087971362.py in <module>
#      24 ax = fig.add_subplot(111, projection = '3d')
#      25 sc = ax.scatter(x, y, z)
# ---> 26 fig.set_color(color= ['black', 'blue', 'green'])
#      27 fig.savefig("adbe.png")
#
# AttributeError: 'Figure' object has no attribute 'set_color'

# %%
def plot_slices(num_rows, num_columns, width, height, data):
    """Plot a montage of 20 CT slices"""
    #data = np.rot90((data))
    #data = np.transpose(data)
    #data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap="gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()

# %%
pixel_height = int(somefunc[0] * 256)
pixel_width = int(somefunc[1] * 256)
pixel_length = int(sqrt(somefunc[0]*256)) * math.floor(sqrt(somefunc[0]*256))

number = display(pixel_height*pixel_width*pixel_length)
display(number)
# Out:
# 5839257600
# None

# %%
import numpy as np
import imageio
import math
from pprint import pprint
images = []
for n in range(0, 1):
    #if n >= somefunc[1] / 90:
        #ax.azim = ax.azim+1.1
    fig.canvas.draw()
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
    #display(sum(int(somefunc[0]) * 256, int(somefunc[1]) * 256, 3))
    image_array = image.reshape(int(somefunc[0]) * 256, int(somefunc[1]) * 256, 3, 1)
    images.append(image_array)
    print(image_array.shape)
    display(plot_slices(math.floor(sqrt(somefunc[0]*256)), math.floor(sqrt(somefunc[0]*256)), int(somefunc[0]) * 256, int(somefunc[1]) * 256, image_array))
    #imageio.imsave(f'stringimage_{n}.png', image_array)
    pprint(len(image_array))
#imageio.mimsave("adbe.gif", images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ml/gd9n1t7n4tqftj4c2btcrqrw0000gn/T/ipykernel_20464/123122257.py in <module>
#      10     image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
#      11     #display(sum(int(somefunc[0]) * 256, int(somefunc[1]) * 256, 3))
# ---> 12     image_array = image.reshape(int(somefunc[0]) * 256, int(somefunc[1]) * 256, 3, 1)
#      13     images.append(image_array)
#      14     print(image_array.shape)
#
# ValueError: cannot reshape array of size 8650752 into shape (2048,1280,3,1)

# %%
from PIL import Image
adbe123 = Image.open(r'stringimage_1.png')
splitimage = Image.Image.split(adbe123)
for image in splitimage: 
    image.show()

# %%
#opencv?

# %%
sum(8,6,5,0,7,5,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ml/gd9n1t7n4tqftj4c2btcrqrw0000gn/T/ipykernel_20464/357368462.py in <module>
# ----> 1 sum(8,6,5,0,7,5,2)
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2258
#    2259     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2260                           initial=initial, where=where)
#    2261
#    2262
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# TypeError: Cannot interpret '5' as a data type
